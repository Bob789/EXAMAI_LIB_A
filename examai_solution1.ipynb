# %%
import numpy as np
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV files and display their information
# we handel the missing values and duplicates in the dataframes in each section
print('-' * 20, 'df_items', '-' * 20)
df_items = pd.read_csv("items.csv")
display(df_items.info())
display(df_items.describe())
display(df_items.head())

print('-' * 20, 'df_order_items', '-' * 20)
df_order_items = pd.read_csv("order_item.csv")
display(df_order_items.info())
display(df_order_items.describe())
display(df_order_items.head())

print('-' * 20, 'df_orders', '-' * 20)
df_orders = pd.read_csv("orders.csv")
display(df_orders.info())
display(df_orders.describe())
display(df_orders.head())

print('-' * 20, 'df_customers', '-' * 20)
df_customers = pd.read_csv("customers.csv")
display(df_customers.info())
display(df_customers.describe())
display(df_customers.head())
# Out:
# -------------------- df_items --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50 non-null     int64
#  1   item_name          50 non-null     object
#  2   item_category      39 non-null     object
#  3   item_price         50 non-null     float64
#  4   stock_quantity     45 non-null     float64
#  5   item_brand         42 non-null     object
#  6   item_availability  50 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB
# None
#              id   item_price  stock_quantity
# count  50.00000    50.000000       45.000000
# mean   25.50000  2222.082600      743.155556
# std    14.57738  1394.005145      332.855071
# min     1.00000   241.540000       14.000000
# 25%    13.25000  1004.360000      550.000000
# 50%    25.50000  1956.220000      704.000000
# 75%    37.75000  3436.830000      971.000000
# max    50.00000  4471.270000     1367.000000
#    id           item_name                item_category  item_price  \
# 0  26       Action Camera        Photography Equipment     2694.25
# 1  37  Antivirus Software                     Software     4186.62
# 2  11      Blu-Ray Player  Video Players and Recorders     3382.86
# 3  25           Camcorder        Photography Equipment      860.01
# 4   7              Camera        Photography Equipment     2366.72
#
#    stock_quantity item_brand  item_availability
# 0             NaN       Bose              False
# 1             NaN        NaN              False
# 2           704.0       ASUS               True
# 3           870.0       Bose               True
# 4           458.0  Microsoft               True
# -------------------- df_order_items --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1000 non-null   int64
#  1   order_id  1000 non-null   int64
#  2   item_id   960 non-null    float64
#  3   quantity  1000 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 31.4 KB
# None
#                 id     order_id     item_id     quantity
# count  1000.000000  1000.000000  960.000000  1000.000000
# mean    500.500000   305.006000   25.746875     3.016000
# std     288.819436   171.251432   14.676686     2.288882
# min       1.000000     1.000000    1.000000     1.000000
# 25%     250.750000   157.000000   13.000000     1.000000
# 50%     500.500000   315.000000   26.000000     2.000000
# 75%     750.250000   450.000000   38.000000     4.000000
# max    1000.000000   599.000000   50.000000     9.000000
#    id  order_id  item_id  quantity
# 0   1       337     10.0         2
# 1   2       430     27.0         6
# 2   3       430     36.0         2
# 3   4       508     46.0         1
# 4   5       229     27.0         2
# -------------------- df_orders --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          600 non-null    int64
#  1   customer_id       555 non-null    float64
#  2   delivery_address  600 non-null    object
#  3   delivery_days     525 non-null    float64
#  4   order_date        600 non-null    object
#  5   payment_method    600 non-null    object
#  6   order_source      600 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 32.9+ KB
# None
#          order_id  customer_id  delivery_days
# count  600.000000   555.000000     525.000000
# mean   300.500000   258.650450       3.899048
# std    173.349358   146.002993       1.075091
# min      1.000000     1.000000       1.000000
# 25%    150.750000   136.000000       3.000000
# 50%    300.500000   256.000000       4.000000
# 75%    450.250000   385.000000       5.000000
# max    600.000000   500.000000       6.000000
#    order_id  customer_id    delivery_address  delivery_days  order_date  \
# 0         1        477.0  576 Cordelia Place            2.0  2023-12-05
# 1         2         93.0      4664 6th Drive            4.0  2023-08-17
# 2         3        474.0      8766 4th Point            4.0  2023-02-25
# 3         4        333.0       31 Bonner Way            3.0  2023-02-04
# 4         5        436.0   20352 Shelley Way            5.0  2023-06-01
#
#   payment_method order_source
# 0      GIFT_CARD      WEBSITE
# 1           CASH        STORE
# 2          CHECK        STORE
# 3           CASH        STORE
# 4           CASH        STORE
# -------------------- df_customers --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            500 non-null    int64
#  1   first_name    494 non-null    object
#  2   last_name     494 non-null    object
#  3   gender        447 non-null    object
#  4   age           475 non-null    float64
#  5   nationallity  494 non-null    object
#  6   joining_date  439 non-null    object
#  7   phone_number  500 non-null    object
#  8   email         500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB
# None
#                id         age
# count  500.000000  475.000000
# mean   250.500000   44.006316
# std    144.481833   14.813395
# min      1.000000    2.000000
# 25%    125.750000   34.000000
# 50%    250.500000   44.000000
# 75%    375.250000   55.000000
# max    500.000000   84.000000
#    id first_name  last_name  gender   age nationallity joining_date  \
# 0   1      Eadie     Maffeo  Female  41.0       France   11/01/2022
# 1   2     Hammad  Brewerton    Male  56.0       Isreal   30/09/2022
# 2   3    Terrell       Bris    Male  43.0        India          NaN
# 3   4    Frannie   Morewood    Male  84.0       France   26/05/2021
# 4   5      Sophi      Fleet  Female  33.0       Sweden   19/07/2021
#
#    phone_number                      email
# 0  534-341-9052        emaffeo0@smh.com.au
# 1  999-994-0510  hbrewerton1@discovery.com
# 2  980-455-5208            tbris2@yale.edu
# 3  979-187-1493  fmorewood3@vistaprint.com
# 4  991-853-9984         sfleet4@unicef.org

# %%
# Level 1: Dataframe of all rows with item_name duplicate
df_dup = df_items[
    df_items.groupby('item_name')['id'].transform('count') > 1
].copy()
display('# Level 1: Dataframe of all rows with emails duplicate', df_dup)
# Out:
# '# Level 1: Dataframe of all rows with emails duplicate'
#     id    item_name                   item_category  item_price  \
# 4    7       Camera           Photography Equipment     2366.72
# 5   48       Camera           Photography Equipment     2039.08
# 6   28       Camera                             NaN      695.71
# 9    3      Desktop       Computers and Accessories     1121.84
# 10  44      Desktop       Computers and Accessories      723.59
# 11  24        Drone        Televisions and Displays     4449.99
# 12  16        Drone                             NaN     3949.97
# 13  10        Drone        Televisions and Displays      453.85
# 18   8    Headphone                             NaN     3117.19
# 19  49    Headphone                 Audio Equipment     1317.56
# 21   2       Laptop       Computers and Accessories     1851.32
# 22  43       Laptop       Computers and Accessories     4153.61
# 29   6      Printer   Printers and Office Equipment     4175.99
# 30  47      Printer   Printers and Office Equipment     3704.16
# 31  17  Smart Watch        Televisions and Displays      312.88
# 32  14  Smart Watch                             NaN     2007.43
# 33   4   Smartphone  Mobile Devices and Accessories      965.20
# 34  45   Smartphone  Mobile Devices and Accessories     3513.56
# 35   9      Speaker                             NaN     4471.27
# 36  50      Speaker                 Audio Equipment     4453.90
# 38   5       Tablet                             NaN     2739.61
# 39  46       Tablet  Mobile Devices and Accessories     1606.65
# 40   1   Television        Televisions and Displays      356.81
# 41  42   Television                             NaN      479.19
# 42  40   Television        Televisions and Displays     2055.66
#
#     stock_quantity item_brand  item_availability
# 4            458.0  Microsoft               True
# 5            471.0  Panasonic               True
# 6              NaN       Sony              False
# 9            334.0         HP               True
# 10          1119.0        JBL               True
# 11           443.0    Samsung               True
# 12           850.0        NaN               True
# 13           605.0        NaN               True
# 18           599.0        NaN               True
# 19             NaN       Sony              False
# 21           493.0         HP               True
# 22          1018.0       Dell               True
# 29           971.0       Sony               True
# 30           239.0    Toshiba               True
# 31           685.0      Canon               True
# 32           742.0        NaN               True
# 33           201.0       Bose               True
# 34          1162.0  Panasonic               True
# 35          1360.0        NaN               True
# 36           937.0   Logitech               True
# 38           190.0    Toshiba               True
# 39           267.0         HP               True
# 40          1009.0        JBL               True
# 41           670.0        NaN               True
# 42          1072.0        NaN               True

# %%
# Level 2: Adding column 'filled_count' to df which counts the number of non-null values in each row
df_dup['filled_count'] = df_dup.notnull().sum(axis=1)
display("# Level 2: Adding column 'filled_count' to df which counts the number of non-null values in each row",df_dup)
print(" Total rows in df_dup: ", len(df_dup))
# Out:
# "# Level 2: Adding column 'filled_count' to df which counts the number of non-null values in each row"
#     id    item_name                   item_category  item_price  \
# 4    7       Camera           Photography Equipment     2366.72
# 5   48       Camera           Photography Equipment     2039.08
# 6   28       Camera                             NaN      695.71
# 9    3      Desktop       Computers and Accessories     1121.84
# 10  44      Desktop       Computers and Accessories      723.59
# 11  24        Drone        Televisions and Displays     4449.99
# 12  16        Drone                             NaN     3949.97
# 13  10        Drone        Televisions and Displays      453.85
# 18   8    Headphone                             NaN     3117.19
# 19  49    Headphone                 Audio Equipment     1317.56
# 21   2       Laptop       Computers and Accessories     1851.32
# 22  43       Laptop       Computers and Accessories     4153.61
# 29   6      Printer   Printers and Office Equipment     4175.99
# 30  47      Printer   Printers and Office Equipment     3704.16
# 31  17  Smart Watch        Televisions and Displays      312.88
# 32  14  Smart Watch                             NaN     2007.43
# 33   4   Smartphone  Mobile Devices and Accessories      965.20
# 34  45   Smartphone  Mobile Devices and Accessories     3513.56
# 35   9      Speaker                             NaN     4471.27
# 36  50      Speaker                 Audio Equipment     4453.90
# 38   5       Tablet                             NaN     2739.61
# 39  46       Tablet  Mobile Devices and Accessories     1606.65
# 40   1   Television        Televisions and Displays      356.81
# 41  42   Television                             NaN      479.19
# 42  40   Television        Televisions and Displays     2055.66
#
#     stock_quantity item_brand  item_availability  filled_count
# 4            458.0  Microsoft               True             7
# 5            471.0  Panasonic               True             7
# 6              NaN       Sony              False             5
# 9            334.0         HP               True             7
# 10          1119.0        JBL               True             7
# 11           443.0    Samsung               True             7
# 12           850.0        NaN               True             5
# 13           605.0        NaN               True             6
# 18           599.0        NaN               True             5
# 19             NaN       Sony              False             6
# 21           493.0         HP               True             7
# 22          1018.0       Dell               True             7
# 29           971.0       Sony               True             7
# 30           239.0    Toshiba               True             7
# 31           685.0      Canon               True             7
# 32           742.0        NaN               True             5
# 33           201.0       Bose               True             7
# 34          1162.0  Panasonic               True             7
# 35          1360.0        NaN               True             5
# 36           937.0   Logitech               True             7
# 38           190.0    Toshiba               True             6
# 39           267.0         HP               True             7
# 40          1009.0        JBL               True             7
# 41           670.0        NaN               True             5
# 42          1072.0        NaN               True             6
#  Total rows in df_dup:  25

# %%
# Level 3: Find the most complete row for each item_name
df_keep = df_dup.loc[
    df_dup.groupby('item_name')['filled_count'].idxmax()
].copy()
df_keep = df_keep.drop(columns=['filled_count'])
display("# Level 3: Find the best rows for each email", df_keep)
print("numbers of rows in df_keep: ", len(df_keep))
# Out:
# '# Level 3: Find the best rows for each email'
#     id    item_name                   item_category  item_price  \
# 4    7       Camera           Photography Equipment     2366.72
# 9    3      Desktop       Computers and Accessories     1121.84
# 11  24        Drone        Televisions and Displays     4449.99
# 19  49    Headphone                 Audio Equipment     1317.56
# 21   2       Laptop       Computers and Accessories     1851.32
# 29   6      Printer   Printers and Office Equipment     4175.99
# 31  17  Smart Watch        Televisions and Displays      312.88
# 33   4   Smartphone  Mobile Devices and Accessories      965.20
# 36  50      Speaker                 Audio Equipment     4453.90
# 39  46       Tablet  Mobile Devices and Accessories     1606.65
# 40   1   Television        Televisions and Displays      356.81
#
#     stock_quantity item_brand  item_availability
# 4            458.0  Microsoft               True
# 9            334.0         HP               True
# 11           443.0    Samsung               True
# 19             NaN       Sony              False
# 21           493.0         HP               True
# 29           971.0       Sony               True
# 31           685.0      Canon               True
# 33           201.0       Bose               True
# 36           937.0   Logitech               True
# 39           267.0         HP               True
# 40          1009.0        JBL               True
# numbers of rows in df_keep:  11

# %%
# level 3.1 keep the id drop so we can search this id for replacement in other tables the correct id 
idx_drop = df_dup.index.difference(df_keep.index)
display("# level 3.1 keep the id drop so we can search this id foe replacement in other tables the correct id ",idx_drop)
print("numbers rows to delete ",len(idx_drop))
# Out:
# '# level 3.1 keep the id drop so we can search this id foe replacement in other tables the correct id '
# Index([5, 6, 10, 12, 13, 18, 22, 30, 32, 34, 35, 38, 41, 42], dtype='int64')
# numbers rows to delete  14

# %%
# Level 3.2: DataFrame of all other duplicate rows to drop for replacement
df_drop = df_dup.loc[idx_drop].copy()
df_drop = df_drop.drop(columns=['filled_count'])
display("Level 3.2: DataFrame of rows to drop", df_drop)
print("numbers of rows in df_drop: ", len(df_drop))
# Out:
# 'Level 3.2: DataFrame of rows to drop'
#     id    item_name                   item_category  item_price  \
# 5   48       Camera           Photography Equipment     2039.08
# 6   28       Camera                             NaN      695.71
# 10  44      Desktop       Computers and Accessories      723.59
# 12  16        Drone                             NaN     3949.97
# 13  10        Drone        Televisions and Displays      453.85
# 18   8    Headphone                             NaN     3117.19
# 22  43       Laptop       Computers and Accessories     4153.61
# 30  47      Printer   Printers and Office Equipment     3704.16
# 32  14  Smart Watch                             NaN     2007.43
# 34  45   Smartphone  Mobile Devices and Accessories     3513.56
# 35   9      Speaker                             NaN     4471.27
# 38   5       Tablet                             NaN     2739.61
# 41  42   Television                             NaN      479.19
# 42  40   Television        Televisions and Displays     2055.66
#
#     stock_quantity item_brand  item_availability
# 5            471.0  Panasonic               True
# 6              NaN       Sony              False
# 10          1119.0        JBL               True
# 12           850.0        NaN               True
# 13           605.0        NaN               True
# 18           599.0        NaN               True
# 22          1018.0       Dell               True
# 30           239.0    Toshiba               True
# 32           742.0        NaN               True
# 34          1162.0  Panasonic               True
# 35          1360.0        NaN               True
# 38           190.0    Toshiba               True
# 41           670.0        NaN               True
# 42          1072.0        NaN               True
# numbers of rows in df_drop:  14

# %%
# Level 4: Choose the rows with no duplicates as unique
df_unique = df_items[
    df_items.groupby('item_name')['id'].transform('count') == 1
].copy()
display("# Level 4: Choose the rows with no duplicates as unique", df_unique)
print("numbers of rows in df_unique: ", len(df_unique))

print("The numbers rows that we should get ofter the replacement is ", len(df_unique) + len(df_keep))
# Out:
# '# Level 4: Choose the rows with no duplicates as unique'
#     id            item_name                   item_category  item_price  \
# 0   26        Action Camera           Photography Equipment     2694.25
# 1   37   Antivirus Software                        Software     4186.62
# 2   11       Blu-Ray Player     Video Players and Recorders     3382.86
# 3   25            Camcorder           Photography Equipment      860.01
# 7   18     Computer Monitor       Computers and Accessories     4076.35
# 8   27          Dash Camera           Photography Equipment     1283.99
# 14  21  External Hard Drive       Computers and Accessories     1251.36
# 15  15      Fitness Tracker  Mobile Devices and Accessories     2997.29
# 16  30         Gaming Chair                Gaming Equipment      417.16
# 17  34           HDMI Cable                          Cables     1710.84
# 20  19             Keyboard       Computers and Accessories      604.18
# 23  23        Micro SD Card                 Storage Devices     3238.23
# 24  36                Modem                             NaN     3256.88
# 25  20                Mouse       Computers and Accessories     1333.04
# 26  38      Office Software   Printers and Office Equipment     3454.82
# 27  32     Portable Charger  Mobile Devices and Accessories     1523.27
# 28  39          Power Strip   Printers and Office Equipment     3344.90
# 37  33      Surge Protector   Printers and Office Equipment      488.39
# 43  22      USB Flash Drive                             NaN     1150.87
# 44  13           Video Game                             NaN     1890.03
# 45  12   Video Game Console                Gaming Equipment      689.61
# 46  41           VR Headset                             NaN     1905.01
# 47  29               Webcam   Printers and Office Equipment     4227.36
# 48  35         Wi-Fi Router               Network Equipment     3812.53
# 49  31     Wireless Charger  Mobile Devices and Accessories      241.54
#
#     stock_quantity item_brand  item_availability
# 0              NaN       Bose              False
# 1              NaN        NaN              False
# 2            704.0       ASUS               True
# 3            870.0       Bose               True
# 7           1205.0       Bose               True
# 8            550.0     Lenovo               True
# 14          1013.0  Microsoft               True
# 15           956.0      Apple               True
# 16           704.0    Samsung               True
# 17           869.0        JBL               True
# 20             NaN  Panasonic              False
# 23           663.0       Sony               True
# 24           673.0       Bose               True
# 25           881.0   Logitech               True
# 26           643.0        JBL               True
# 27           192.0         HP               True
# 28          1211.0         HP               True
# 37           800.0       ASUS               True
# 43          1251.0  Panasonic               True
# 44           681.0     Lenovo               True
# 45           753.0  Microsoft               True
# 46          1367.0        JBL               True
# 47           596.0       Dell               True
# 48            14.0  Microsoft               True
# 49           951.0     Lenovo               True
# numbers of rows in df_unique:  25
# The numbers rows that we should get ofter the replacement is  36

# %%
# Level 5: merge the two dataframes
df_final = pd.concat([df_unique, df_keep], ignore_index=True)
display("# Level 5: merge the two dataframes",df_final)
print("numbers of rows in df_final: ", len(df_final))
# Out:
# '# Level 5: merge the two dataframes'
#     id            item_name                   item_category  item_price  \
# 0   26        Action Camera           Photography Equipment     2694.25
# 1   37   Antivirus Software                        Software     4186.62
# 2   11       Blu-Ray Player     Video Players and Recorders     3382.86
# 3   25            Camcorder           Photography Equipment      860.01
# 4   18     Computer Monitor       Computers and Accessories     4076.35
# 5   27          Dash Camera           Photography Equipment     1283.99
# 6   21  External Hard Drive       Computers and Accessories     1251.36
# 7   15      Fitness Tracker  Mobile Devices and Accessories     2997.29
# 8   30         Gaming Chair                Gaming Equipment      417.16
# 9   34           HDMI Cable                          Cables     1710.84
# 10  19             Keyboard       Computers and Accessories      604.18
# 11  23        Micro SD Card                 Storage Devices     3238.23
# 12  36                Modem                             NaN     3256.88
# 13  20                Mouse       Computers and Accessories     1333.04
# 14  38      Office Software   Printers and Office Equipment     3454.82
# 15  32     Portable Charger  Mobile Devices and Accessories     1523.27
# 16  39          Power Strip   Printers and Office Equipment     3344.90
# 17  33      Surge Protector   Printers and Office Equipment      488.39
# 18  22      USB Flash Drive                             NaN     1150.87
# 19  13           Video Game                             NaN     1890.03
# 20  12   Video Game Console                Gaming Equipment      689.61
# 21  41           VR Headset                             NaN     1905.01
# 22  29               Webcam   Printers and Office Equipment     4227.36
# 23  35         Wi-Fi Router               Network Equipment     3812.53
# 24  31     Wireless Charger  Mobile Devices and Accessories      241.54
# 25   7               Camera           Photography Equipment     2366.72
# 26   3              Desktop       Computers and Accessories     1121.84
# 27  24                Drone        Televisions and Displays     4449.99
# 28  49            Headphone                 Audio Equipment     1317.56
# 29   2               Laptop       Computers and Accessories     1851.32
# 30   6              Printer   Printers and Office Equipment     4175.99
# 31  17          Smart Watch        Televisions and Displays      312.88
# 32   4           Smartphone  Mobile Devices and Accessories      965.20
# 33  50              Speaker                 Audio Equipment     4453.90
# 34  46               Tablet  Mobile Devices and Accessories     1606.65
# 35   1           Television        Televisions and Displays      356.81
#
#     stock_quantity item_brand  item_availability
# 0              NaN       Bose              False
# 1              NaN        NaN              False
# 2            704.0       ASUS               True
# 3            870.0       Bose               True
# 4           1205.0       Bose               True
# 5            550.0     Lenovo               True
# 6           1013.0  Microsoft               True
# 7            956.0      Apple               True
# 8            704.0    Samsung               True
# 9            869.0        JBL               True
# 10             NaN  Panasonic              False
# 11           663.0       Sony               True
# 12           673.0       Bose               True
# 13           881.0   Logitech               True
# 14           643.0        JBL               True
# 15           192.0         HP               True
# 16          1211.0         HP               True
# 17           800.0       ASUS               True
# 18          1251.0  Panasonic               True
# 19           681.0     Lenovo               True
# 20           753.0  Microsoft               True
# 21          1367.0        JBL               True
# 22           596.0       Dell               True
# 23            14.0  Microsoft               True
# 24           951.0     Lenovo               True
# 25           458.0  Microsoft               True
# 26           334.0         HP               True
# 27           443.0    Samsung               True
# 28             NaN       Sony              False
# 29           493.0         HP               True
# 30           971.0       Sony               True
# 31           685.0      Canon               True
# 32           201.0       Bose               True
# 33           937.0   Logitech               True
# 34           267.0         HP               True
# 35          1009.0        JBL               True
# numbers of rows in df_final:  36

# %%
# Step 1: Prepare DataFrames for ID replacement ***************************
#   - df_drop: rows to remove, with 'id' renamed to old_id
#   - df_keep: rows to keep, with 'id' renamed to new_id

df_drop_map = df_drop[['item_name', 'id']].rename(columns={'id': 'old_id'})
df_keep_map = df_keep[['item_name', 'id']].rename(columns={'id': 'new_id'})

# Step 2: Merge on 'email' to build an old_id → new_id mapping table
df_id_map = pd.merge(
    df_drop_map,
    df_keep_map,
    on='item_name',
    how='left'
)

# df_id_map now contains columns 'item_name', 'old_id', and 'new_id'
display("# Step 2: Merge on 'item_name' to build an old_id → new_id mapping table",df_id_map)

# Step 3: Convert the mapping DataFrame to a dict for use with replace()
id_map = dict(zip(df_id_map['old_id'], df_id_map['new_id']))

# Display the mapping dictionary for verification
print("# Step 3: Convert the mapping DataFrame to a dict for use with replace()", id_map)

#---------------- checking the rows before changing ------------------
mask = df_order_items['item_id'].isin(df_drop_map['old_id'])
print("numbers of rows in df_order_items that we will change ", len(df_order_items[mask]))

# create DataFrame with the original index of the rows to be updated
rows_original = df_order_items[mask].copy()
display("rows to be updated: ", rows_original)

original_df_order_items = df_order_items['item_id'].copy()

#---------------- checking the mapping ------------------

# Step 4: Apply the replacement to df_order_items
df_order_items['item_id'] = (
    df_order_items['item_id']
    .replace(id_map)
)

# Verify the replacement
changed_rows = (original_df_order_items != df_order_items['item_id']).sum()
print(f"The number of changed rows whose affected: {changed_rows}")
# Out:
# "# Step 2: Merge on 'item_name' to build an old_id → new_id mapping table"
#       item_name  old_id  new_id
# 0        Camera      48       7
# 1        Camera      28       7
# 2       Desktop      44       3
# 3         Drone      16      24
# 4         Drone      10      24
# 5     Headphone       8      49
# 6        Laptop      43       2
# 7       Printer      47       6
# 8   Smart Watch      14      17
# 9    Smartphone      45       4
# 10      Speaker       9      50
# 11       Tablet       5      46
# 12   Television      42       1
# 13   Television      40       1
# # Step 3: Convert the mapping DataFrame to a dict for use with replace() {48: 7, 28: 7, 44: 3, 16: 24, 10: 24, 8: 49, 43: 2, 47: 6, 14: 17, 45: 4, 9: 50, 5: 46, 42: 1, 40: 1}
# numbers of rows in df_order_items that we will change  256
# 'rows to be updated: '
#        id  order_id  item_id  quantity
# 0       1       337     10.0         2
# 6       7       547     40.0         3
# 7       8       547     10.0         3
# 13     14       290     47.0         3
# 16     17       197      9.0         8
# ..    ...       ...      ...       ...
# 982   983       486     48.0         3
# 983   984       217     44.0         6
# 986   987       357     43.0         2
# 997   998       472     10.0         3
# 999  1000       337     16.0         1
#
# [256 rows x 4 columns]
# The number of changed rows whose affected: 296

# %%
# Step 5: Drop rows with missing at least 3 values in df_customers
print("numbers of rows in df_customers before drop ", len(df_customers))
df_customers_cleaned = df_customers.dropna(thresh=len(df_customers.columns) - 2)
print("numbers of rows in df_customers_cleaned after drop ", len(df_customers_cleaned))


df_order_items_cleaned = df_order_items[
    df_order_items['id'].isin(df_customers_cleaned['id'])
].copy()
# Out:
# numbers of rows in df_customers before drop  500
# numbers of rows in df_customers_cleaned after drop  494

# %%
# 2.1 Average item price
average_price = df_items['item_price'].mean()
print("Average item price:", average_price)
# Out:
# Average item price: 2222.0825999999997

# %%
# 2.2 The customer who purchased the most items

# Merge order items with orders to get customer_id for each item
merged = df_order_items.merge(df_orders, on='order_id')

# Group by customer_id and calculate the total quantity each customer purchased
total_quantity_per_customer = merged.groupby('customer_id')['quantity'].sum()

# Find the customer_id with the highest total quantity
top_customer_id = total_quantity_per_customer.idxmax()
top_customer_quantity = total_quantity_per_customer.max()

# 🔁 NEW: Merge orders with customers to get full customer info
merged_orders_customers = df_orders.merge(df_customers, left_on='customer_id', right_on='id')

# Extract the row with the top customer ID
top_customer_details = merged_orders_customers[merged_orders_customers['customer_id'] == top_customer_id]

# Print result
print("Top customer ID:", top_customer_id)
print("Total quantity purchased:", top_customer_quantity)
print("Customer details:")
print(top_customer_details[['first_name', 'last_name', 'email', 'delivery_address']])
# Out:
# Top customer ID: 138.0
# Total quantity purchased: 45
# Customer details:
#     first_name last_name                  email     delivery_address
# 192     Ellary    Ledner  eledner3t@latimes.com   4 Pennsylvania Way
# 206     Ellary    Ledner  eledner3t@latimes.com         7 Ryan Court
# 255     Ellary    Ledner  eledner3t@latimes.com      1 Colorado Pass
# 414     Ellary    Ledner  eledner3t@latimes.com      53910 Grim Park
# 514     Ellary    Ledner  eledner3t@latimes.com  92961 Lunder Avenue

# %%
# 2.1 Graph 

# --- Filter out customers with missing gender values ---
df_customers_cleaned = df_customers.dropna(subset=['gender'])

# --- Count customers by gender 
gender_counts = df_customers_cleaned['gender'].value_counts()
print("Customers by gender:")
print(gender_counts)
gender_counts.plot(kind='bar', title='Customers by Gender')
plt.ylabel('Number of Customers')
plt.xlabel('Gender')
plt.tight_layout()
plt.show()
print("\n")

# --- Count customers by nationality 
nationality_counts = df_customers_cleaned['nationallity'].value_counts()
print("Customers by nationality:")
print(nationality_counts)
nationality_counts.plot(kind='bar', title='Customers by Nationality')
plt.ylabel('Number of Customers')
plt.xlabel('Nationality')
plt.tight_layout()
plt.show()
# Out:
# Customers by gender:
# gender
# Female         203
# Male           196
# Agender         13
# Genderfluid     12
# Non-binary       7
# Polygender       6
# Bigender         5
# Genderqueer      5
# Name: count, dtype: int64
# Customers by nationality:
# nationallity
# United States    88
# Isreal           62
# South Korea      29
# Italy            28
# France           27
# Brazil           26
# India            24
# Chile            24
# Japan            22
# Argentina        22
# Peru             20
# Spain            19
# Sweden           17
# China            17
# Germany          16
# Name: count, dtype: int64
